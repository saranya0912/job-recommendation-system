# %%
from __future__ import unicode_literals
import json #  json package iteratively parse the json file instead of reading it all in at once
import sys,os
import pandas as pd
from pandas import DataFrame
from pandas.io.json import json_normalize #package for flattening json in pandas df
import numpy as np
import scipy
import math
import random
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import csv

# %%
user=pd.read_csv('C:/Users/Agnes Sandra/Documents/job_recommendation/users_interactions.csv')

# %%
user.head()
# Out:
#     timestamp eventType     contentId      personId     sessionId  \
# 0  1465413032      VIEW -3.499920e+18 -8.845300e+18  1.264200e+18
# 1  1465412560      VIEW  8.890720e+18 -1.032020e+18  3.621740e+18
# 2  1465416190      VIEW  3.105150e+17 -1.130270e+18  2.631860e+18
# 3  1465413895    FOLLOW  3.105150e+17  3.442810e+17 -3.167640e+18
# 4  1465412290      VIEW -7.820640e+18 -4.453370e+17  5.611480e+18
#
#                                            userAgent userRegion userCountry
# 0                                                NaN        NaN         NaN
# 1  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2...         NY          US
# 2                                                NaN        NaN         NaN
# 3                                                NaN        NaN         NaN
# 4                                                NaN        NaN         NaN

# %%
user1=pd.read_csv('C:/Users/Agnes Sandra/Documents/job_recommendation/shared_articles.csv')

# %%
user1.head()
# Out:
#     timestamp        eventType            contentId       authorPersonId  \
# 0  1459192779  CONTENT REMOVED -6451309518266745024  4340306774493623681
# 1  1459193988   CONTENT SHARED -4110354420726924665  4340306774493623681
# 2  1459194146   CONTENT SHARED -7292285110016212249  4340306774493623681
# 3  1459194474   CONTENT SHARED -6151852268067518688  3891637997717104548
# 4  1459194497   CONTENT SHARED  2448026894306402386  4340306774493623681
#
#        authorSessionId authorUserAgent authorRegion authorCountry contentType  \
# 0  8940341205206233829             NaN          NaN           NaN        HTML
# 1  8940341205206233829             NaN          NaN           NaN        HTML
# 2  8940341205206233829             NaN          NaN           NaN        HTML
# 3 -1457532940883382585             NaN          NaN           NaN        HTML
# 4  8940341205206233829             NaN          NaN           NaN        HTML
#
#                                                  url  \
# ...

# %%
data=pd.read_csv('C:/Users/Agnes Sandra/Documents/job_recommendation/data_science_extract.csv')

# %%
data.head()
# Out:
#    s_no                                         DegreeType  \
# 0     0  [ Btech: Food Technology,  National Diploma: F...
# 1     1                          [B.Econ, Grade 12/Matric]
# 2     2  [Bsc in Computer Systems, Higher National Dipl...
# 3     3             [Advanced Diploma In Computer Science]
# 4     4                               [Mobile develipment]
#
#                                       employer_names  \
# 0  [Cape Herb & Spice, Greys Marine, Heinz Foods,...
# 1  [Careerjunction, Gijima, Lateral Dynamics, Lei...
# 2                [Bruce Records Studio, Crystal MAP]
# 3                     [Dynamic Data, Exor Petroleum]
# 4                                   [MCA Consulting]
#
#                                     future_jobtitles  \
# 0  [Food technologist, New product development, a...
# 1                                                 []
# 2  [Web Developer, Application Developer, C# Deve...
# 3                                                 []
# ...

# %%
f,ax=plt.subplots(figsize=(15,5))
data['DegreeType'].value_counts().head(10).plot(kind = 'bar')

# %%
f,ax=plt.subplots(figsize=(15,5))
data['skills'].value_counts().head(10).plot(kind = 'bar')
